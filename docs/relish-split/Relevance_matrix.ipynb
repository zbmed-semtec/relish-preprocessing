# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split


# Load the data
# data = pd.read_csv('data/output/relish-ground-truth/RELISH.tsv', delimiter='\t', header=None)
data = pd.read_csv('RELISH.tsv', delimiter='\t', header=None)
print('Initial pairs in relevance matrix:', len(data))

# Get the unique reference articles
refDocs = np.unique(data[0])  # First column
print('Length of unique reference articles:', len(refDocs))

# Get the unique assessed articles
asdDocs = np.unique(data[1])
print('Length of unique assessed articles:', len(asdDocs))

# Find reference articles if they do not exist in PID2
onlyRefDocs = [pid for pid in refDocs if pid not in asdDocs]  # Second column
print('Length of reference articles that do not exist as assessed articles:',len(onlyRefDocs))

# Assuming onlyRefDocs is the list of reference articles that do not exist as assessed articles
onlyRefDocs_data = data[data[0].isin(onlyRefDocs)]

# Find reference articles if they exist in PID2
notonlyRefDocs = [pid for pid in refDocs if pid in asdDocs]  # Second column
print('Length of reference articles that also exist as assessed articles:', len(notonlyRefDocs))

# Filter data based on onlyRefDocs
refRelMatrix = data[data[0].isin(onlyRefDocs)]  # Filter based on PID1
print('Total pairs after filtering:', len(refRelMatrix))

# Save the pairs being removed to 'valid.tsv'
valid_data = data[~data[0].isin(onlyRefDocs)]
valid_data.to_csv('valid.tsv', sep='\t', header=None, index=False)

# # Remove the corresponding pairs from data
# refRelMatrix = data[~data[1].isin(refDocs)]  # Filter based on PID2

# Initialize variables to store the best split
best_split = None
best_error = float('inf')
total_rows_initial = len(refRelMatrix)  # Total rows in the original refRelMatrix

# Loop for 1000 iterations
for i in range(1000):
    # Generate a different seed for each iteration
    np.random.seed(i)

    # Split onlyRefDocs into 80/20
    # train_onlyRef, test_onlyRef = train_test_split(onlyRefDocs, test_size=0.2)

    # Use 'Relevance' as the stratification variable
    train_data, test_data = train_test_split(onlyRefDocs_data, test_size=0.2, random_state=42, stratify=onlyRefDocs_data[2])

    # Filter refRelMatrix based on train_onlyRef
    ref_rel_train = refRelMatrix[refRelMatrix[0].isin(train_onlyRef)]  # Filter based on PID1

    # Update refRelMatrix by removing rows corresponding to train_onlyRef
    ref_rel_test = refRelMatrix[~refRelMatrix[0].isin(train_onlyRef)]  # Update based on PID1

    # Print out the size of train_onlyRef, ref_rel_train, and total rows in train and test for debugging
    total_rows_train_test = len(train_onlyRef) + len(test_onlyRef)
    print(f"Iteration {i+1}: Train OnlyRefDocs size: {len(train_onlyRef)}, Ref Rel Train size: {len(ref_rel_train)}, "
          f"Total rows in train and test: {total_rows_train_test}", f"Total pairs: {total_rows_initial}")

    # Find the percentage of those pairs in the 80-split
    train_percentage = len(ref_rel_train) / total_rows_initial

    # Calculate the error from 80%
    error = abs(train_percentage - 0.8)

    # Check if this split gives the closest pairs split to 80%
    if error < best_error:
        best_error = error
        best_split = (train_onlyRef, test_onlyRef, ref_rel_train, ref_rel_test)

    # Break the loop if all pairs have been exhausted
    if len(refRelMatrix) == 0:
        print("All pairs have been exhausted.")
        break

# Report best results
if best_split:
    best_train_onlyRef, best_test_onlyRef, ref_rel_train, ref_rel_test = best_split
    print("Best Split Found:")
    print(f"Train Data Size by PMID: {len(best_train_onlyRef)}, Test Data Size by PMID: {len(best_test_onlyRef)}")
    print(f"Train Data Size Pairs: {len(ref_rel_train)}, Test Data Size Pairs: {len(ref_rel_test)}")
    print(f"Percentage of Pairs in Train Data: {len(ref_rel_train) / total_rows_initial}")
    print(f"Percentage of Pairs in Test Data: {len(ref_rel_test) / total_rows_initial}")
    print(f"Error from 80%: {best_error}")

    # # Save the best train and test splits to separate files
    df = pd.DataFrame(ref_rel_train).to_csv('train_split.tsv', sep='\t', index=False)
    df = pd.DataFrame(ref_rel_test).to_csv('test_split.tsv', sep='\t', index=False)
else:
    print("No iterations performed.")
# Out:
# Initial pairs in relevance matrix: 189884
# Length of unique reference articles: 3194
# Length of unique assessed articles: 159792
# Length of reference articles that do not exist as assessed articles: 2108
# Length of reference articles that also exist as assessed articles: 1086
# Total pairs after filtering: 125307
# Iteration 1: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 2: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 3: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 4: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 5: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 6: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 7: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 8: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 9: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 10: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 11: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 12: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 13: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 14: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 15: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 16: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 17: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 18: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 19: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 20: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 21: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 22: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 23: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 24: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 25: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 26: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 27: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 28: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 29: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 30: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 31: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 32: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 33: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 34: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 35: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 36: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 37: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 38: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 39: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 40: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 41: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 42: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 43: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 44: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 45: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 46: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 47: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 48: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 49: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 50: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 51: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 52: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 53: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 54: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 55: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 56: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 57: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 58: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 59: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 60: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 61: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 62: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 63: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 64: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 65: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 66: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 67: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 68: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 69: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 70: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 71: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 72: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 73: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 74: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 75: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 76: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 77: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 78: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 79: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 80: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 81: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 82: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 83: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 84: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 85: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 86: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 87: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 88: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 89: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 90: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 91: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 92: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 93: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 94: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 95: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 96: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 97: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 98: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 99: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 100: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 101: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 102: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 103: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 104: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 105: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 106: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 107: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 108: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 109: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 110: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 111: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 112: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 113: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 114: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 115: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 116: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 117: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 118: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 119: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 120: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 121: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 122: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 123: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 124: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 125: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 126: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 127: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 128: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 129: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 130: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 131: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 132: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 133: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 134: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 135: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 136: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 137: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 138: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 139: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 140: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 141: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 142: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 143: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 144: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 145: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 146: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 147: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 148: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 149: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 150: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 151: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 152: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 153: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 154: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 155: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 156: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 157: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 158: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 159: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 160: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 161: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 162: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 163: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 164: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 165: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 166: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 167: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 168: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 169: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 170: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 171: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 172: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 173: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 174: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 175: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 176: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 177: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 178: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 179: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 180: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 181: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 182: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 183: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 184: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 185: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 186: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 187: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 188: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 189: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 190: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 191: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 192: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 193: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 194: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 195: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 196: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 197: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 198: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 199: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration 200: Train OnlyRefDocs size: 1686, Ref Rel Train size: 100126, Total rows in train and test: 2108 Total pairs: 125307
# Iteration